# %%
import requests

url = "https://api.sportradar.com/tennis/trial/v3/en/double_competitors_rankings.json?api_key=Peab8MyrHuoAenp8rM7RpOaEv7eLImIuaj6HB7Cj"

headers = {"accept": "application/json"}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"generated_at":"2025-01-30T16:28:07+00:00","rankings":[{"type_id":2,"name":"ATP","year":2025,"week":5,"gender":"men","competitor_rankings":[{"rank":1,"movement":0,"points":7530,"competitions_played":22,"competitor":{"id":"sr:competitor:49363","name":"Pavic, Mate","country":"Croatia","country_code":"HRV","abbreviation":"PAV"}},{"rank":1,"movement":0,"points":7530,"competitions_played":22,"competitor":{"id":"sr:competitor:51836","name":"Arevalo-Gonzalez, Marcelo","country":"El Salvador","country_code":"SLV","abbreviation":"ARE"}},{"rank":3,"movement":10,"points":7075,"competitions_played":31,"competitor":{"id":"sr:competitor:637970","name":"Patten, Henry","country":"Great Britain","country_code":"GBR","abbreviation":"PAT"}},{"rank":4,"movement":10,"points":7055,"competitions_played":28,"competitor":{"id":"sr:competitor:14898","name":"Heliovaara, Harri","country":"Finland","country_code":"FIN","abbreviation":"HEL"}},{"rank":5,"movement":-2,"points":6475,"competitions_played":21,"compet
# ...

# %%
import requests

# API URL and headers
url = "https://api.sportradar.com/tennis/trial/v3/en/double_competitors_rankings.json?api_key=Peab8MyrHuoAenp8rM7RpOaEv7eLImIuaj6HB7Cj"
headers = {"accept": "application/json"}

# Make the GET request
response = requests.get(url, headers=headers)

# Parse the JSON response
data = response.json()

# Extract and display the timestamp
generated_at = data.get("generated_at", "N/A")
print(f"Generated At: {generated_at}\n")

# Loop through the rankings list
for ranking in data.get("rankings", []):
    print(f"Ranking Type ID: {ranking.get('type_id', 'N/A')}")
    print(f"Ranking Name: {ranking.get('name', 'N/A')}")
    print(f"Year: {ranking.get('year', 'N/A')}")
    print(f"Week: {ranking.get('week', 'N/A')}")
    print(f"Gender: {ranking.get('gender', 'N/A')}")
    print("=" * 50)
    
    # Loop through the competitor rankings
    for competitor_ranking in ranking.get("competitor_rankings", []):
        # Extract competitor ranking details
        Rank_id = competitor_ranking.get("id", "N/A")
        Rank = competitor_ranking.get("rank", "N/A")
        Movement = competitor_ranking.get("movement", "N/A")
        Points = competitor_ranking.get("points", "N/A")
        Competitions_played = competitor_ranking.get("competitions_played", "N/A")
        
        # Extract competitor details
        competitor = competitor_ranking.get("competitor", {})
        Competitor_id = competitor.get("id", "N/A")
        Name = competitor.get("name", "N/A")
        Country = competitor.get("country", "N/A")
        Country_code = competitor.get("country_code", "N/A")
        Abbreviation = competitor.get("abbreviation", "N/A")
        
        # Print details with updated column names
        print(f"  Rank_id: {Rank_id}")
        print(f"  Rank: {Rank}")
        print(f"  Movement: {Movement}")
        print(f"  Points: {Points}")
        print(f"  Competitions_played: {Competitions_played}")
        print(f"  Competitor_id: {Competitor_id}")
        print(f"  Name: {Name}")
        print(f"  Country: {Country}")
        print(f"  Country_code: {Country_code}")
        print(f"  Abbreviation: {Abbreviation}")
        print("-" * 50)
    print("=" * 50)
# Out:
# Generated At: 2025-01-30T16:28:07+00:00
#
# Ranking Type ID: 2
# Ranking Name: ATP
# Year: 2025
# Week: 5
# Gender: men
# ...
#   Rank_id: N/A
#   Rank: 1
#   Movement: 0
#   Points: 7530
#   Competitions_played: 22
#   Competitor_id: sr:competitor:49363
#   Name: Pavic, Mate
#   Country: Croatia
#   Country_code: HRV
#   Abbreviation: PAV
# --------------------------------------------------
#   Rank_id: N/A
#   Rank: 1
#   Movement: 0
#   Points: 7530
#   Competitions_played: 22
#   Competitor_id: sr:competitor:51836
#   Name: Arevalo-Gonzalez, Marcelo
#   Country: El Salvador
#   Country_code: SLV
#   Abbreviation: ARE
# --------------------------------------------------
#   Rank_id: N/A
#   Rank: 3
#   Movement: 10
#   Points: 7075
#   Competitions_played: 31
#   Competitor_id: sr:competitor:637970
#   Name: Patten, Henry
#   Country: Great Britain
#   Country_code: GBR
#   Abbreviation: PAT
# --------------------------------------------------
#   Rank_id: N/A
#   Rank: 4
# ...
